# %%
import pandas as pd
import numpy as np

# %%
df2=pd.read_csv(r"C:\Users\mbsas\OneDrive\Dokumenty\4th semester\Artificial Intelligence\Lab\Project\60 seconds grouped datasets\scene002.csv")

# %%
df2
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# 8   1531883994        -0.017895        -0.001914        -0.005319
# 9   1531883995        -0.025752         0.009256        -0.018391
# 10  1531883996         0.007736        -0.011848        -0.012200
# 11  1531883997        -0.006893        -0.002605        -0.011061
# 12  1531883998         0.007166         0.004096        -0.006215
# ...

# %%
df1=pd.read_csv(r"C:\Users\mbsas\OneDrive\Dokumenty\4th semester\Artificial Intelligence\Lab\Project\Final data\Severity 1.csv")

# %%
df1
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883530         0.006161        -0.005749         0.319221
# 1   1531883531        -0.001484        -0.002749         0.374249
# 2   1531883532        -0.008093        -0.001479         0.352713
# 3   1531883533        -0.003526        -0.005735         0.092298
# 4   1531883534        -0.005878         0.008739         0.000413
# ..         ...              ...              ...              ...
# 60  1531883590        -0.003417         0.000971        -0.011419
# 61  1531883591         0.001258        -0.000081        -0.017089
# 62  1531883592         0.008223         0.004565        -0.045726
# 63  1531883593         0.011239         0.008016        -0.041045
# 64  1531883594         0.005386         0.010025        -0.032484
#
#     linear_accel_x  linear_accel_y  linear_accel_z  brake_sensor  \
# 0        -0.041864        1.322542        9.758100      0.170893
# ...

# %%
empty_rows = pd.DataFrame(0, index=range(5), columns=df2.columns)

df_before = df2.iloc[:28]
df_after = df2.iloc[28:]
df_updated = pd.concat([df_before, empty_rows, df_after]).reset_index(drop=True)
df_updated['Severity'] = 0

# %%
start_time = df_updated['utime'].iloc[0]
df_updated['utime'] = range(start_time, start_time + len(df_updated))
# Update the 'severity' column for rows 28 to 33
empty_rows = pd.DataFrame(0, index=range(5), columns=df2.columns)

df_before = df2.iloc[:28]
df_after = df2.iloc[28:]
df_updated = pd.concat([df_before, empty_rows, df_after]).reset_index(drop=True)
df_updated['Severity'] = 0
df_updated.loc[28:32, 'Severity'] = 2

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_updated
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# 8   1531883994        -0.017895        -0.001914        -0.005319
# 9   1531883995        -0.025752         0.009256        -0.018391
# 10  1531883996         0.007736        -0.011848        -0.012200
# 11  1531883997        -0.006893        -0.002605        -0.011061
# 12  1531883998         0.007166         0.004096        -0.006215
# ...

# %%
changes = {
    'rotation_rate_x': 25,
    'rotation_rate_y': 25,
    'rotation_rate_z': 25,
    'linear_accel_x': -50,
    'linear_accel_y': 25,
    'linear_accel_z': 25,
    'brake_sensor': 100,
    'steering_sensor': 50,
    'throttle_sensor': -25,
    'meanEffTorque': -25,
    'FL_wheel_speed': -25,
    'FR_wheel_speed': -25,
    'RL_wheel_speed': -25,
    'RR_wheel_speed': -25,
    'value': -25,
    'brake': 100,
    'steering': 25,
    'steering_speed': 50,
    'throttle': -25,
    'vehicle_speed': -50,
}

def apply_changes(row, prev_row):
    for column, change in changes.items():
        row[column] = prev_row[column] * (1 + change / 100)
    return row

df_updated.iloc[28] = apply_changes(df_updated.iloc[28], df_updated.iloc[27])
# Out:
# C:\Users\mbsas\AppData\Local\Temp\ipykernel_13992\1865746974.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row[column] = prev_row[column] * (1 + change / 100)

# %%
df_updated
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# 8   1531883994        -0.017895        -0.001914        -0.005319
# 9   1531883995        -0.025752         0.009256        -0.018391
# 10  1531883996         0.007736        -0.011848        -0.012200
# 11  1531883997        -0.006893        -0.002605        -0.011061
# 12  1531883998         0.007166         0.004096        -0.006215
# ...

# %%
df_updated.at[27, 'brake'] =4.5 # 100% increase
df_updated.at[27, 'throttle'] = 80.3

# %%
df_updated
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# 8   1531883994        -0.017895        -0.001914        -0.005319
# 9   1531883995        -0.025752         0.009256        -0.018391
# 10  1531883996         0.007736        -0.011848        -0.012200
# 11  1531883997        -0.006893        -0.002605        -0.011061
# 12  1531883998         0.007166         0.004096        -0.006215
# ...

# %%
df=df_updated
changes = {
    'rotation_rate_x': 10,
    'rotation_rate_y': 10,
    'rotation_rate_z': 10,
    'linear_accel_x': -20,
    'linear_accel_y': 10,
    'linear_accel_z': 10,
    'brake_sensor': 50,
    'steering_sensor': 20,
    'throttle_sensor': -10,
    'meanEffTorque': -10,
    'FL_wheel_speed': -10,
    'FR_wheel_speed': -10,
    'RL_wheel_speed': -10,
    'RR_wheel_speed': -10,
    'value': -10,
    'brake': 50,
    'steering': 20,
    'steering_speed': 20,
    'throttle': -10,
    'vehicle_speed': -20,
}
def apply_changes(row, prev_row):
    for column, change in changes.items():
        row[column] = prev_row[column] * (1 + change / 100)
    return row
df.iloc[29] = apply_changes(df.iloc[29], df.iloc[28])
df
# Out:
# C:\Users\mbsas\AppData\Local\Temp\ipykernel_13992\154900200.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row[column] = prev_row[column] * (1 + change / 100)
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# ...

# %%
changes = {
    'rotation_rate_x': -32,
    'rotation_rate_y': -32,
    'rotation_rate_z': -32,
    'linear_accel_x': 65,
    'linear_accel_y': -32,
    'linear_accel_z': -32,
    'brake_sensor': -33,
    'steering_sensor': -43,
    'throttle_sensor': 32,
    'meanEffTorque': 32,
    'FL_wheel_speed': 32,
    'FR_wheel_speed': 32,
    'RL_wheel_speed': 32,
    'RR_wheel_speed': 32,
    'value': 32,
    'brake': 0,
    'steering': -43,
    'steering_speed': -43,
    'throttle': 32,
    'vehicle_speed': 70,
}

def apply_changes(row, prev_row):
    for column, change in changes.items():
        row[column] = prev_row[column] * (1 + change / 100)
    return row

df.iloc[32] = apply_changes(df.iloc[32], df.iloc[31])

df
# Out:
# C:\Users\mbsas\AppData\Local\Temp\ipykernel_13992\3079779325.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row[column] = prev_row[column] * (1 + change / 100)
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# ...

# %%
df.at[32,'brake_sensor']=0.2384764

# %%
df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531883986         0.003417         0.000229        -0.002207
# 1   1531883987         0.011590        -0.011055        -0.000887
# 2   1531883988        -0.007692        -0.008565         0.003863
# 3   1531883989        -0.001272         0.001571         0.005564
# 4   1531883990         0.001226         0.001949         0.001963
# 5   1531883991         0.018034        -0.005613         0.006534
# 6   1531883992         0.011038         0.010702         0.022085
# 7   1531883993         0.001360         0.005749         0.011654
# 8   1531883994        -0.017895        -0.001914        -0.005319
# 9   1531883995        -0.025752         0.009256        -0.018391
# 10  1531883996         0.007736        -0.011848        -0.012200
# 11  1531883997        -0.006893        -0.002605        -0.011061
# 12  1531883998         0.007166         0.004096        -0.006215
# ...

# %%
updated_csv_path = r'C:\Users\mbsas\Downloads\waste.csv'
df.to_csv(updated_csv_path, index=False)

# %%
df=pd.read_csv(r"C:\Users\mbsas\OneDrive\Dokumenty\4th semester\Artificial Intelligence\Lab\Project\60 seconds grouped datasets\scene003.csv")

# %%
empty_rows = pd.DataFrame(0, index=range(5), columns=df.columns)

df= pd.concat([df, empty_rows]).reset_index(drop=True)
df['Severity'] = 0

# %%
df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531884258        -0.000311        -0.001305         0.006264
# 1   1531884259        -0.003454        -0.009133         0.005673
# 2   1531884260        -0.001728        -0.007819         0.001898
# 3   1531884261        -0.000390         0.005011         0.002925
# 4   1531884262         0.008355         0.003443        -0.003179
# 5   1531884263        -0.016379        -0.008785        -0.002826
# 6   1531884264        -0.007611         0.000323         0.003802
# 7   1531884265         0.010961         0.004957         0.008904
# 8   1531884266         0.015519         0.013925         0.031655
# 9   1531884267        -0.001630         0.009177         0.123714
# 10  1531884268         0.003068        -0.009357         0.268644
# 11  1531884269         0.001927         0.002862         0.392644
# 12  1531884270         0.005051        -0.005894         0.243125
# ...

# %%
start_time = df['utime'].iloc[0]
df['utime'] = range(start_time, start_time + len(df_updated))

df.loc[58:62, 'Severity'] = 3
df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531884258        -0.000311        -0.001305         0.006264
# 1   1531884259        -0.003454        -0.009133         0.005673
# 2   1531884260        -0.001728        -0.007819         0.001898
# 3   1531884261        -0.000390         0.005011         0.002925
# 4   1531884262         0.008355         0.003443        -0.003179
# 5   1531884263        -0.016379        -0.008785        -0.002826
# 6   1531884264        -0.007611         0.000323         0.003802
# 7   1531884265         0.010961         0.004957         0.008904
# 8   1531884266         0.015519         0.013925         0.031655
# 9   1531884267        -0.001630         0.009177         0.123714
# 10  1531884268         0.003068        -0.009357         0.268644
# 11  1531884269         0.001927         0.002862         0.392644
# 12  1531884270         0.005051        -0.005894         0.243125
# ...

# %%
exclude_index = 0 
excluded_row = df.iloc[[exclude_index]]
rest_of_df = df.drop(exclude_index)

multiplied_df = rest_of_df * 4

result_df = pd.concat([excluded_row, multiplied_df])

# %%
exclude_index = 0 
excluded_row = df.iloc[[exclude_index]]
rest_of_df = df.drop(exclude_index)

multiplied_df = rest_of_df * 4

result_df = pd.concat([excluded_row, multiplied_df])
start_time = result_df['utime'].iloc[0]
result_df['utime'] = range(start_time, start_time + len(result_df))
result_df=result_df.drop(index=0)

# %%
result_df=result_df.drop(index=0)
result_df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884259        -0.013817        -0.036533         0.022694
# 2   1531884260        -0.006911        -0.031274         0.007590
# 3   1531884261        -0.001559         0.020043         0.011701
# 4   1531884262         0.033419         0.013774        -0.012717
# 5   1531884263        -0.065515        -0.035139        -0.011305
# 6   1531884264        -0.030444         0.001294         0.015207
# 7   1531884265         0.043846         0.019829         0.035617
# 8   1531884266         0.062077         0.055700         0.126621
# 9   1531884267        -0.006519         0.036708         0.494857
# 10  1531884268         0.012270        -0.037428         1.074574
# 11  1531884269         0.007706         0.011450         1.570574
# 12  1531884270         0.020203        -0.023577         0.972499
# 13  1531884271         0.032195        -0.021284        -0.026487
# ...

# %%
df=result_df
df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884259        -0.013817        -0.036533         0.022694
# 2   1531884260        -0.006911        -0.031274         0.007590
# 3   1531884261        -0.001559         0.020043         0.011701
# 4   1531884262         0.033419         0.013774        -0.012717
# 5   1531884263        -0.065515        -0.035139        -0.011305
# 6   1531884264        -0.030444         0.001294         0.015207
# 7   1531884265         0.043846         0.019829         0.035617
# 8   1531884266         0.062077         0.055700         0.126621
# 9   1531884267        -0.006519         0.036708         0.494857
# 10  1531884268         0.012270        -0.037428         1.074574
# 11  1531884269         0.007706         0.011450         1.570574
# 12  1531884270         0.020203        -0.023577         0.972499
# 13  1531884271         0.032195        -0.021284        -0.026487
# ...

# %%
changes = {
    'rotation_rate_x': 50,
    'rotation_rate_y': 50,
    'rotation_rate_z': 50,
    'linear_accel_x': -97,
    'linear_accel_y': 50,
    'linear_accel_z': 50,
    'brake_sensor': 10,
    'steering_sensor': 97,
    'throttle_sensor': -50,
    'meanEffTorque': -50,
    'FL_wheel_speed': -50,
    'FR_wheel_speed': -50,
    'RL_wheel_speed': -50,
    'RR_wheel_speed': -50,
    'value': -50,
    'brake': 10,
    'steering': 97,
    'steering_speed': 97,
    'throttle': -50,
    'vehicle_speed': -97,
}

def apply_changes(row, prev_row):
    for column, change in changes.items():
        row[column] = prev_row[column] * (1 + change / 100)
    return row
result_df.iloc[61] = apply_changes(result_df.iloc[61], result_df.iloc[60])
result_df
# Out:
# C:\Users\mbsas\AppData\Local\Temp\ipykernel_13992\463137860.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row[column] = prev_row[column] * (1 + change / 100)
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884259        -0.013817        -0.036533         0.022694
# 2   1531884260        -0.006911        -0.031274         0.007590
# 3   1531884261        -0.001559         0.020043         0.011701
# 4   1531884262         0.033419         0.013774        -0.012717
# 5   1531884263        -0.065515        -0.035139        -0.011305
# 6   1531884264        -0.030444         0.001294         0.015207
# 7   1531884265         0.043846         0.019829         0.035617
# 8   1531884266         0.062077         0.055700         0.126621
# ...

# %%
result_df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884259        -0.013817        -0.036533         0.022694
# 2   1531884260        -0.006911        -0.031274         0.007590
# 3   1531884261        -0.001559         0.020043         0.011701
# 4   1531884262         0.033419         0.013774        -0.012717
# 5   1531884263        -0.065515        -0.035139        -0.011305
# 6   1531884264        -0.030444         0.001294         0.015207
# 7   1531884265         0.043846         0.019829         0.035617
# 8   1531884266         0.062077         0.055700         0.126621
# 9   1531884267        -0.006519         0.036708         0.494857
# 10  1531884268         0.012270        -0.037428         1.074574
# 11  1531884269         0.007706         0.011450         1.570574
# 12  1531884270         0.020203        -0.023577         0.972499
# 13  1531884271         0.032195        -0.021284        -0.026487
# ...

# %%
updated_csv_path = r'C:\Users\mbsas\Downloads\waste.csv'
result_df.to_csv(updated_csv_path, index=False)

# %%
df=pd.read_csv(r"C:\Users\mbsas\OneDrive\Dokumenty\4th semester\Artificial Intelligence\Lab\Project\60 seconds grouped datasets\scene004.csv")

# %%
df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 0   1531884391        -0.005587         0.008361        -0.301858
# 1   1531884392         0.006470        -0.010783        -0.097560
# 2   1531884393        -0.010242        -0.004827        -0.023134
# 3   1531884394        -0.006413         0.014206         0.001544
# 4   1531884395        -0.005059        -0.002877         0.005647
# 5   1531884396         0.008141        -0.005264        -0.004071
# 6   1531884397        -0.000406         0.000701         0.003961
# 7   1531884398        -0.002684         0.006315         0.002470
# 8   1531884399         0.001242        -0.001661         0.001912
# 9   1531884400         0.004123        -0.000456         0.003076
# 10  1531884401         0.000489        -0.001534         0.001755
# 11  1531884402         0.000995        -0.001643         0.003236
# 12  1531884403        -0.006352         0.002572        -0.000911
# ...

# %%
empty_rows = pd.DataFrame(0, index=range(5), columns=df.columns)

df= pd.concat([df, empty_rows]).reset_index(drop=True)
df['Severity'] = 0
exclude_index = 0 
excluded_row = df.iloc[[exclude_index]]
rest_of_df = df.drop(exclude_index)

multiplied_df = rest_of_df * 4

result_df = pd.concat([excluded_row, multiplied_df])
start_time = result_df['utime'].iloc[0]
result_df['utime'] = range(start_time, start_time + len(result_df))
result_df=result_df.drop(index=0)
result_df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884392         0.025882        -0.043132        -0.390239
# 2   1531884393        -0.040967        -0.019306        -0.092534
# 3   1531884394        -0.025653         0.056824         0.006176
# 4   1531884395        -0.020236        -0.011507         0.022589
# 5   1531884396         0.032565        -0.021058        -0.016285
# 6   1531884397        -0.001625         0.002802         0.015843
# 7   1531884398        -0.010735         0.025260         0.009880
# 8   1531884399         0.004966        -0.006645         0.007647
# 9   1531884400         0.016492        -0.001824         0.012306
# 10  1531884401         0.001957        -0.006135         0.007021
# 11  1531884402         0.003980        -0.006573         0.012945
# 12  1531884403        -0.025407         0.010290        -0.003645
# 13  1531884404        -0.013145         0.016982        -0.000592
# ...

# %%
changes = {
    'rotation_rate_x': 50,
    'rotation_rate_y': 50,
    'rotation_rate_z': 50,
    'linear_accel_x': -99,
    'linear_accel_y': 50,
    'linear_accel_z': 50,
    'brake_sensor': 10,
    'steering_sensor': 99.8,
    'throttle_sensor': -50,
    'meanEffTorque': -50,
    'FL_wheel_speed': -99.8,
    'FR_wheel_speed': -99.8,
    'RL_wheel_speed': -99.8,
    'RR_wheel_speed': -99.8,
    'value': -50,
    'brake': 10,
    'steering': 99.8,
    'steering_speed': 99.8,
    'throttle': -50,
    'vehicle_speed': -99.8,
}

def apply_changes(row, prev_row):
    for column, change in changes.items():
        row[column] = prev_row[column] * (1 + change / 100)
    return row
result_df.iloc[61] = apply_changes(result_df.iloc[61], result_df.iloc[60])
result_df
# Out:
# C:\Users\mbsas\AppData\Local\Temp\ipykernel_13992\887947836.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row[column] = prev_row[column] * (1 + change / 100)
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884392         0.025882        -0.043132        -0.390239
# 2   1531884393        -0.040967        -0.019306        -0.092534
# 3   1531884394        -0.025653         0.056824         0.006176
# 4   1531884395        -0.020236        -0.011507         0.022589
# 5   1531884396         0.032565        -0.021058        -0.016285
# 6   1531884397        -0.001625         0.002802         0.015843
# 7   1531884398        -0.010735         0.025260         0.009880
# 8   1531884399         0.004966        -0.006645         0.007647
# ...

# %%
result_df=result_df.drop(index=63)
result_df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884392         0.025882        -0.043132        -0.390239
# 2   1531884393        -0.040967        -0.019306        -0.092534
# 3   1531884394        -0.025653         0.056824         0.006176
# 4   1531884395        -0.020236        -0.011507         0.022589
# 5   1531884396         0.032565        -0.021058        -0.016285
# 6   1531884397        -0.001625         0.002802         0.015843
# 7   1531884398        -0.010735         0.025260         0.009880
# 8   1531884399         0.004966        -0.006645         0.007647
# 9   1531884400         0.016492        -0.001824         0.012306
# 10  1531884401         0.001957        -0.006135         0.007021
# 11  1531884402         0.003980        -0.006573         0.012945
# 12  1531884403        -0.025407         0.010290        -0.003645
# 13  1531884404        -0.013145         0.016982        -0.000592
# ...

# %%
result_df.loc[59:62, 'Severity'] = 4

# %%
result_df
# Out:
#          utime  rotation_rate_x  rotation_rate_y  rotation_rate_z  \
# 1   1531884392         0.025882        -0.043132        -0.390239
# 2   1531884393        -0.040967        -0.019306        -0.092534
# 3   1531884394        -0.025653         0.056824         0.006176
# 4   1531884395        -0.020236        -0.011507         0.022589
# 5   1531884396         0.032565        -0.021058        -0.016285
# 6   1531884397        -0.001625         0.002802         0.015843
# 7   1531884398        -0.010735         0.025260         0.009880
# 8   1531884399         0.004966        -0.006645         0.007647
# 9   1531884400         0.016492        -0.001824         0.012306
# 10  1531884401         0.001957        -0.006135         0.007021
# 11  1531884402         0.003980        -0.006573         0.012945
# 12  1531884403        -0.025407         0.010290        -0.003645
# 13  1531884404        -0.013145         0.016982        -0.000592
# ...

# %%
updated_csv_path = r'C:\Users\mbsas\Downloads\waste.csv'
result_df.to_csv(updated_csv_path, index=False)
