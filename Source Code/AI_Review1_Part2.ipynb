# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

url = "https://local-business-data.p.rapidapi.com/search-nearby"

querystring = {"query":"hospital","lat":"12.95356","lng":"80.23347","limit":"100","language":"en","region":"in"}

headers = {
	"X-User-Agent": "desktop",
	"X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
	"X-RapidAPI-Host": "local-business-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'e43efc8c-2a3e-42ab-aa41-9531475cff51', 'parameters': {'query': 'hospital', 'language': 'en', 'region': 'in', 'lat': 12.95356, 'lng': 80.23347, 'limit': 100}, 'data': [{'business_id': '0x3a525cfe5f2be42b:0x40ebf013bcd82a0', 'google_id': '0x3a525cfe5f2be42b:0x40ebf013bcd82a0', 'place_id': 'ChIJK-QrX_5cUjoRoILNOwG_DgQ', 'google_mid': '/g/124syr8w4', 'phone_number': '+919840546672', 'name': 'Nanthini Hospitals', 'latitude': 12.9327914, 'longitude': 80.2317127, 'full_address': 'No 168, Nanthini Hospitals, Old Mahabalipuram Road, Chandrasekhar Avenue, Thoraipakkam, Chennai, Tamil Nadu 600097', 'review_count': 111, 'rating': 2.6, 'timezone': 'Asia/Calcutta', 'opening_status': 'Open 24 hours', 'working_hours': {'Thursday': ['Open 24 hours'], 'Friday': ['Open 24 hours'], 'Saturday': ['Open 24 hours'], 'Sunday': ['Open 24 hours'], 'Monday': ['Open 24 hours'], 'Tuesday': ['Open 24 hours'], 'Wednesday': ['Open 24 hours']}, 'website': 'http://www.nanthinihospital.c
# ...

# %%
import requests

url = "https://local-business-data.p.rapidapi.com/search-nearby"

querystring = {"query":"hospital","lat":"12.95356","lng":"80.23347","limit":"100","language":"en","region":"in"}

headers = {
	"X-User-Agent": "desktop",
	"X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
	"X-RapidAPI-Host": "local-business-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'f71404ad-78a0-4734-a5b3-44bf67a97df9', 'parameters': {'query': 'hospital', 'language': 'en', 'region': 'in', 'lat': 12.95356, 'lng': 80.23347, 'limit': 100}, 'data': [{'business_id': '0x3a525cfe5f2be42b:0x40ebf013bcd82a0', 'google_id': '0x3a525cfe5f2be42b:0x40ebf013bcd82a0', 'place_id': 'ChIJK-QrX_5cUjoRoILNOwG_DgQ', 'google_mid': '/g/124syr8w4', 'phone_number': '+919840546672', 'name': 'Nanthini Hospitals', 'latitude': 12.9327914, 'longitude': 80.2317127, 'full_address': 'No 168, Nanthini Hospitals, Old Mahabalipuram Road, Chandrasekhar Avenue, Thoraipakkam, Chennai, Tamil Nadu 600097', 'review_count': 111, 'rating': 2.6, 'timezone': 'Asia/Calcutta', 'opening_status': 'Open 24 hours', 'working_hours': {'Thursday': ['Open 24 hours'], 'Friday': ['Open 24 hours'], 'Saturday': ['Open 24 hours'], 'Sunday': ['Open 24 hours'], 'Monday': ['Open 24 hours'], 'Tuesday': ['Open 24 hours'], 'Wednesday': ['Open 24 hours']}, 'website': 'http://www.nanthinihospital.c
# ...

# %%
response.json()
# Out:
# {'status': 'OK',
#  'request_id': 'f71404ad-78a0-4734-a5b3-44bf67a97df9',
#  'parameters': {'query': 'hospital',
#   'language': 'en',
#   'region': 'in',
#   'lat': 12.95356,
#   'lng': 80.23347,
#   'limit': 100},
#  'data': [{'business_id': '0x3a525cfe5f2be42b:0x40ebf013bcd82a0',
#    'google_id': '0x3a525cfe5f2be42b:0x40ebf013bcd82a0',
#    'place_id': 'ChIJK-QrX_5cUjoRoILNOwG_DgQ',
#    'google_mid': '/g/124syr8w4',
#    'phone_number': '+919840546672',
#    'name': 'Nanthini Hospitals',
#    'latitude': 12.9327914,
#    'longitude': 80.2317127,
#    'full_address': 'No 168, Nanthini Hospitals, Old Mahabalipuram Road, Chandrasekhar Avenue, Thoraipakkam, Chennai, Tamil Nadu 600097',
#    'review_count': 111,
#    'rating': 2.6,
#    'timezone': 'Asia/Calcutta',
#    'opening_status': 'Open 24 hours',
#    'working_hours': {'Thursday': ['Open 24 hours'],
#     'Friday': ['Open 24 hours'],
#     'Saturday': ['Open 24 hours'],
#     'Sunday': ['Open 24 hours'],
# ...

# %%
import requests

url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

querystring = {"location":"12.95356,80.23347","type":"hospital","radius":"10000","language":"en"}

headers = {
	"X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
	"X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'id': 'AF6AEA3C719753289E8C5C583AD65153', 'name': 'Sri Buvana Shakthi Clinic', 'address': 'No.9, Green Peace, Shakti Apartments, 2nd Main Rd, Sri Sai Nagar, Thoraipakkam, Chennai, Tamil Nadu 600097, India', 'phone_number': '+919092467899', 'location': {'lat': 12.953204, 'lng': 80.234963}, 'types': ['doctor', 'health', 'hospital'], 'distance': 167}, {'id': 'EA84A4994980F0A92D659E13D580B529', 'name': 'SHADITHYA PSYCHIATRIC CLINIC (OMR)', 'address': 'No: 2, SHADITHYA CLINIC, 200 Feet Radial Rd, Sri Sai Nagar, Thoraipakkam, Chennai, Tamil Nadu 600097, India', 'phone_number': '+918925566777', 'website': 'https://www.shadithyahospital.com/outpatients-clinic/', 'location': {'lat': 12.950241, 'lng': 80.235026}, 'types': ['doctor', 'health', 'hospital'], 'distance': 406}, {'id': '3AD010F03F71BCB4D49704BE4F9E3273', 'name': 'Government Veterinary Hospital - Perungudi', 'address': '31, Veera Pandia Kattabomman St, Phase-1, Vijayendra Nagar, Perungudi, Chennai, Tamil Nadu 600096, In
# ...

# %%
import json

file_path = "hospital_data.json"

# Open the file in write mode and save the JSON data
with open(file_path, 'w') as file:
    json.dump(response.json(), file)

print("JSON data saved to:", file_path)
# Out:
# JSON data saved to: hospital_data.json

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\PETDEVI1957\\Downloads'

# %%
def find_places_nearby(place_type,latitude,longitude,radius):
    url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"
    querystring = {"location":str((latitude,longitude)),"type":place_type,"radius":str(radius),"language":"en"}
    headers = {
        "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
        "X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
    }
    response = requests.get(url, headers=headers, params=querystring)
    print(response.json())
    file_path = "hospital_data_"+str((latitude,longitude))+".json"
    return f"The following data has been saved to {file_path}"

# %% [markdown]
# 12.9480,80.1397

# %%
find_places_nearby("hospitals",12.9480,80.1397,5000)
# Out:
# {'error': 'BAD_REQUEST', 'message': 'Invalid location'}
# 'The following data has been saved to hospital_data_(12.948, 80.1397).json'

# %%
import requests

url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

querystring = {"location":"12.9480,80.1397","type":"hospital","radius":"5000","language":"en"}

headers = {
	"X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
	"X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'id': '1EC7C1452A3BE546AB80A9DEDBFC2CDE', 'name': 'Sri Santhanakrishna Padmavathy Health care and Research foundation', 'address': 'W4WR+C2W, Santhana Krishnan St, Nehru Nagar, Chromepet, Chennai, Tamil Nadu 600044, India', 'location': {'lat': 12.946115, 'lng': 80.140077}, 'types': ['health', 'hospital'], 'distance': 214}, {'id': 'AC3F6517723C3ADA323DD2B618978741', 'name': 'Agash Nursing Home - Hospital in Chrompet, Chennai', 'address': 'New Colony, Chromepet, Chennai, Tamil Nadu 600044, India', 'website': 'https://agashnursinghome.com/', 'location': {'lat': 12.949087, 'lng': 80.137972}, 'types': ['health', 'hospital'], 'distance': 223}, {'id': 'F4B9FBBBC565ED57768C3020E7EE16DE', 'name': 'A.Kesava Mudaliyar & Son. கேசவ முதலியார் &sons.', 'address': 'W4XQ+R9V, Grand Southern Trunk Rd, New Colony, Chromepet, Chennai, Tamil Nadu 600047, India', 'location': {'lat': 12.949602, 'lng': 80.138435}, 'types': ['health', 'hospital'], 'distance': 225}, {'id': '4E845274A2D6A5EB9DF59
# ...

# %%
### MIT Coordinates
import requests

url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

querystring = {
    "location": "12.9480,80.1397",
    "type": "hospital",
    "radius": "5000",
    "language": "en"
}

headers = {
    "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
    "X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# Filter hospitals by name or other attributes indicating larger facilities
filtered_hospitals = [hospital for hospital in data['results'] if 'hospital' in hospital['name'].lower()]

print(filtered_hospitals)
# Out:
# [{'id': 'AC3F6517723C3ADA323DD2B618978741', 'name': 'Agash Nursing Home - Hospital in Chrompet, Chennai', 'address': 'New Colony, Chromepet, Chennai, Tamil Nadu 600044, India', 'website': 'https://agashnursinghome.com/', 'location': {'lat': 12.949087, 'lng': 80.137972}, 'types': ['health', 'hospital'], 'distance': 223}, {'id': '4E845274A2D6A5EB9DF59BFE91685DF8', 'name': 'Hospital', 'address': '234, Grand Southern Trunk Rd, Tambaram, Chennai, Tamil Nadu 600044, India', 'location': {'lat': 12.947937, 'lng': 80.137605}, 'types': ['health', 'hospital'], 'distance': 227}, {'id': 'FA5B7459120AB800C4A0053D32FF8029', 'name': 'Dhanvanthri Hospital', 'address': 'Hastinapuram Main Rd, State Bank Staff Colony, Chromepet, Chennai, Tamil Nadu 600044, India', 'location': {'lat': 12.945421, 'lng': 80.139843}, 'types': ['health', 'hospital'], 'distance': 288}, {'id': '5FDF3E4F014946E4061277ED33367E10', 'name': 'RK Speciality Hospital', 'address': 'No-18, Ramachandra Iyer Street, Nehru Nagar, Chromepe
# ...

# %%
import requests

url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

querystring = {
    "location": "12.9412,80.2119",
    "type": "hospital",
    "radius": "10000",
    "language": "en"
}

headers = {
    "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
    "X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# Filter hospitals by name or other attributes indicating larger facilities
filtered_hospitals = [hospital for hospital in data['results'] if 'hospital' in hospital['name'].lower()]

print(filtered_hospitals)
# Out:
# [{'id': 'E3EC52691702749D7E3DABCD6AD68707', 'name': 'Sree Balaji Dental College & Hospital', 'address': 'Velachery Main Rd, Narayanapuram, Pallikaranai, Chennai, Tamil Nadu 600100, India', 'phone_number': '+914422462179', 'website': 'https://sbdch.ac.in/', 'location': {'lat': 12.944357, 'lng': 80.208059}, 'types': ['health', 'hospital', 'university'], 'distance': 545}, {'id': '97BC0863FC5F3D1ADF7BDB55F28B68C3', 'name': 'Standard Health Care Hospital, Physio Fix.', 'address': '46, VGP Rajesh Nagar, Pallikaranai, Chennai, Tamil Nadu 600129, India', 'location': {'lat': 12.942393, 'lng': 80.206096}, 'types': ['health', 'hospital'], 'distance': 644}, {'id': 'E7734BD13A867CB37FEA5FA54DB2885F', 'name': 'DR.KAMAKSHI MEMORIAL HOSPITALS', 'address': '1, 200 Feet Radial Rd, Dandeeswarar Nagar, Rose Avenue, Pallikaranai, Chennai, Tamil Nadu 600100, India', 'phone_number': '+914466300300', 'website': 'https://drkmh.com/', 'location': {'lat': 12.949013, 'lng': 80.209059}, 'types': ['health', 'hosp
# ...

# %% [markdown]
# ### Google Places API

# %% [markdown]
# ### Function2

# %%
import requests

url = "https://map-places.p.rapidapi.com/nearbysearch/json"

querystring = {"location":"12.9480,80.1397","radius":"500","keyword":"hospital","type":"hospital"}

headers = {
	"X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
	"X-RapidAPI-Host": "map-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'html_attributions': [], 'next_page_token': 'AUc7tXXjDS9hCCwdelVyu42BKu5S3DjXMIoYhhj_KvBEUbQLMBpJdubuYxIgJM0z6AglliFza0-l-qPeL0Izgdx1G_AZxc3Cm9GEhoh82wRHJ6rMXLN70V7n1xu5dnGMd15BXPF3Cwp3EM_X8ky0E0YhmLIF7sCYhelQ4RjL7O_AMxVRLUJDGHCKyiYHcXq4-UFKJFBmNbvOvw66n4rS4AycY9bzMErtuLIi0NIOIHPhxUE79gckA_J2-uQKkkMCTVk2EI9tjPBbCJK626ctPeZIE-pQvnhNT_k76796K9DxxPqTq5jJuxS8hZQWifaZ-fpAdNLRwdEqfFKdjQGMIz0RvLH-7inptfAc7fq4htCjgPi3Epxug_y_CTpE0PJwyOSzdDNa3LkM5_RXN3OYfhYdl7B7BQovELcbKt-OuvGdsiL__9mXBWjadoRUKCVk11WUa7It9SY', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 12.9459046, 'lng': 80.1365663}, 'viewport': {'northeast': {'lat': 12.94738422989272, 'lng': 80.13786332989272}, 'southwest': {'lat': 12.94468457010728, 'lng': 80.13516367010729}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/hospital-71.png', 'icon_background_color': '#F88181', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hospital-H_pinlet', 'name': 'P
# ...

# %%
pip install geopy
# Out:
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/125.4 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from geopy.distance import geodesic

def get_distance(source_lat_lng, hospital_lat_lng):
    source_lat, source_lng = source_lat_lng
    hospital_lat, hospital_lng = hospital_lat_lng
    source_point = (source_lat, source_lng)
    hospital_point = (hospital_lat, hospital_lng)
    return geodesic(source_point, hospital_point).kilometers

source_lat_lng = (12.9480, 80.1397)

url = "https://map-places.p.rapidapi.com/nearbysearch/json"

querystring = {
    "location": "12.9480,80.1397",
    "radius": "500",
    "keyword": "hospital",
    "type": "hospital"
}

headers = {
    "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
    "X-RapidAPI-Host": "map-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()

results = data.get('results', [])

for result in results:
    hospital_name = result.get('name', 'N/A')
    address = result.get('vicinity', 'N/A')
    phone_number = result.get('formatted_phone_number', 'N/A')
    hospital_lat_lng = (result['geometry']['location']['lat'], result['geometry']['location']['lng'])
    distance = get_distance(source_lat_lng, hospital_lat_lng)
    
    print(f"Hospital Name: {hospital_name}")
    print(f"Phone Number: {phone_number}")
    print(f"Address: {address}")
    print(f"Distance from Source Latitude: {distance:.2f} km")
    print()
# Out:
# Hospital Name: PARVATHY HOSPITAL
# Phone Number: N/A
# Address: 241, Grand Southern Trunk Rd, near MIT Bridge, Kamakshi Colony, Chromepet, Chennai
# Distance from Source Latitude: 0.41 km
#
# Hospital Name: Sayee Hospitals
# Phone Number: N/A
# Address: No.14, Bashyam Street, Radha Nagar Main Rd, T.Nagar, Radha Nagar, Chromepet, Chennai
# Distance from Source Latitude: 0.61 km
#
# Hospital Name: Chennai Krishna Hospital
# Phone Number: N/A
# Address: 297, Grand Southern Trunk Rd, near MIT Bridge, Kamakshi Colony, Chromepet, Chennai
# Distance from Source Latitude: 0.36 km
#
# Hospital Name: RK Speciality Hospital
# Phone Number: N/A
# Address: No-18, Ramachandra Iyer Street, Nehru Nagar, Chromepet, Chennai
# Distance from Source Latitude: 0.33 km
#
# Hospital Name: Gajanan Hospital Pvt Ltd AG Hospital
# Phone Number: N/A
# Address: Radha Nagar, No. 30, South Street, Doctors Colony, Chromepet, Chennai
# Distance from Source Latitude: 0.51 km
#
# ...

# %%
import requests
from geopy.distance import geodesic

def get_distance(source_lat_lng, hospital_lat_lng):
    source_lat, source_lng = source_lat_lng
    hospital_lat, hospital_lng = hospital_lat_lng
    source_point = (source_lat, source_lng)
    hospital_point = (hospital_lat, hospital_lng)
    return geodesic(source_point, hospital_point).kilometers

source_lat_lng = (12.935572, 80.213930)

url = "https://map-places.p.rapidapi.com/nearbysearch/json"

querystring = {
    "location": "12.935572,80.213930",
    "radius": "5000",
    "keyword": "hospital",
    "type": "hospital"
}

headers = {
    "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
    "X-RapidAPI-Host": "map-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()

results = data.get('results', [])

for result in results:
    hospital_name = result.get('name', 'N/A')
    address = result.get('vicinity', 'N/A')
    phone_number = result.get('formatted_phone_number', 'N/A')
    hospital_lat_lng = (result['geometry']['location']['lat'], result['geometry']['location']['lng'])
    distance = get_distance(source_lat_lng, hospital_lat_lng)
    
    print(f"Hospital Name: {hospital_name}")
    print(f"Phone Number: {phone_number}")
    print(f"Address: {address}")
    print(f"Distance from Source Latitude: {distance:.2f} km")
    print()
# Out:
# Hospital Name: Saraswathy Multispeciality Hospital
# Phone Number: N/A
# Address: 92/A, Bazaar Main Rd, Sastri Nagar, Madipakkam, Chennai
# Distance from Source Latitude: 3.40 km
#
# Hospital Name: Apollo Multi Speciality Hospital
# Phone Number: N/A
# Address: 5/639, Rajiv Gandhi Salai, Tirumalai Nagar, Perungudi, Chennai
# Distance from Source Latitude: 4.62 km
#
# Hospital Name: Dr. KAMAKSHI MULTISPECIALITY CLINIC
# Phone Number: N/A
# Address: 9, 1010, Velachery - Tambaram Main Rd, United Colony, V.G.P Pushpa Nagar, Ranganathapuram, Medavakkam, Chennai
# Distance from Source Latitude: 3.42 km
#
# Hospital Name: AM Hospital
# Phone Number: N/A
# Address: No.11, 710, Medavakkam Main Rd, Kovilambakkam, Chennai
# Distance from Source Latitude: 3.46 km
#
# Hospital Name: Anitha Hospital
# Phone Number: N/A
# Address: 5279, 9th St, Puzhuthivakkam, Srinivasa Nagar, Ram Nagar, Madipakkam, Chennai
# Distance from Source Latitude: 3.85 km
#
# ...

# %% [markdown]
# ### Combination API

# %%
import requests

url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

querystring = {"location":"12.94738422989272,80.13786332989272","type":"hospital","radius":"10000","language":"en"}

headers = {
	"X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
	"X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'id': '4E845274A2D6A5EB9DF59BFE91685DF8', 'name': 'Hospital', 'address': '234, Grand Southern Trunk Rd, Tambaram, Chennai, Tamil Nadu 600044, India', 'location': {'lat': 12.947937, 'lng': 80.137605}, 'types': ['health', 'hospital'], 'distance': 68}, {'id': '1B52EBCAE1654F58EC89B82BEC07C9E5', 'name': 'suji Siddha Clinic Dr. N.S. Kanthal B.S.M.S', 'address': 'suji siddha ayurveda vaiththiyasalaI Dr. N.S.Kanthal B.S.M.S 1, 13th Cross Street, New Colony, Chromepet, Chennai, Tamil Nadu 600047, India', 'phone_number': '+917397383061', 'location': {'lat': 12.947936, 'lng': 80.137028}, 'types': ['health', 'hospital'], 'distance': 109}, {'id': '862CE6D3C5372AA590E274A23547A34B', 'name': 'Dr.Ramya pediatrician (Muktha clinic)', 'address': '94, National Hwy 32, New Colony, Chromepet, Chennai, Tamil Nadu 600047, India', 'location': {'lat': 12.948506, 'lng': 80.137582}, 'types': ['health', 'hospital'], 'distance': 129}, {'id': 'EB83B3D479FB1821EB1171DA9F154369', 'name': 'PACHAIYAPPA
# ...

# %% [markdown]
# ### Function1

# %%
import requests
import json

url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

querystring = {
    "location": "12.94738422989272,80.13786332989272",
    "type": "hospital",
    "radius": "50000",
    "language": "en"
}

headers = {
    "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
    "X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()

# Parsing the JSON response
results = data.get('results', [])

filtered_hospitals = [hospital for hospital in results if 'hospital' in hospital.get('name', '').lower()]

for hospital in filtered_hospitals:
    hospital_name = hospital.get('name', 'N/A')
    address = hospital.get('address', 'N/A')
    phone_number = hospital.get('phone_number', 'N/A')
    location = hospital.get('location', {})
    hospital_lat_lng = (location.get('lat', 'N/A'), location.get('lng', 'N/A'))
    distance = hospital.get('distance', 'N/A')
    
    print(f"Hospital Name: {hospital_name}")
    print(f"Phone Number: {phone_number}")
    print(f"Address: {address}")
    print(f"Latitude: {hospital_lat_lng[0]}, Longitude: {hospital_lat_lng[1]}")
    print(f"Distance: {distance} meters")
    print()
# Out:
# Hospital Name: Hospital
# Phone Number: N/A
# Address: 234, Grand Southern Trunk Rd, Tambaram, Chennai, Tamil Nadu 600044, India
# Latitude: 12.947937, Longitude: 80.137605
# Distance: 68 meters
#
# Hospital Name: Chennai Krishna Hospital
# Phone Number: +919444786535
# Address: 297, Grand Southern Trunk Rd, near MIT Bridge, Kamakshi Colony, Chromepet, Chennai, Tamil Nadu 600044, India
# Latitude: 12.946433, Longitude: 80.136784
# Distance: 158 meters
#
# Hospital Name: Agash Nursing Home - Hospital in Chrompet, Chennai
# Phone Number: N/A
# Address: New Colony, Chromepet, Chennai, Tamil Nadu 600044, India
# Latitude: 12.949087, Longitude: 80.137972
# Distance: 190 meters
#
# Hospital Name: PARVATHY HOSPITAL
# Phone Number: +914422382248
# Address: 241, Grand Southern Trunk Rd, near MIT Bridge, Kamakshi Colony, Chromepet, Chennai, Tamil Nadu 600044, India
# Latitude: 12.945916, Longitude: 80.136576
# Distance: 215 meters
#
# Hospital Name: Dhanvanthri Hospital
# Phone Number: N/A
# ...

# %% [markdown]
# # The Demonstration

# %% [markdown]
# ### Installation of the necessary files

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Google Maps API

# %%
import requests
from geopy.distance import geodesic

def get_distance(source_lat_lng, hospital_lat_lng):
    source_lat, source_lng = source_lat_lng
    hospital_lat, hospital_lng = hospital_lat_lng
    source_point = (source_lat, source_lng)
    hospital_point = (hospital_lat, hospital_lng)
    return geodesic(source_point, hospital_point).kilometers

def get_hospital_details(source_lat_lng, radius):
    
    url = "https://map-places.p.rapidapi.com/nearbysearch/json"

    querystring = {
        "location": ", ".join(str(coord) for coord in source_lat_lng),
        "radius": str(radius),
        "keyword": "hospital",
        "type": "hospital"
    }

    headers = {
        "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
        "X-RapidAPI-Host": "map-places.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    data = response.json()

    results = data.get('results', [])

    hospital_dict = {}

    for result in results:
        hospital_name = result.get('name', 'N/A')
        address = result.get('vicinity', 'N/A')
        phone_number = result.get('formatted_phone_number', 'N/A')
        hospital_lat_lng = (result['geometry']['location']['lat'], result['geometry']['location']['lng'])
        distance = get_distance(source_lat_lng, hospital_lat_lng)

        hospital_info = {
            'Phone Number': phone_number,
            'Address': address,
            'Distance from Source Latitude': f"{distance:.2f} km",
            'Latitude': hospital_lat_lng[0],
            'Longitude': hospital_lat_lng[1]
        }

        hospital_dict[hospital_name] = hospital_info

    """ Traverse the dictionary keys and print hospital information
    for hospital_name in hospital_dict:
        print(f"Hospital Name: {hospital_name}")
        hospital_info = hospital_dict[hospital_name]
        for key, value in hospital_info.items():
            print(f"{key}: {value}")
        print()"""
    
    return hospital_dict

# %%
result_dictionary = get_hospital_details((12.9480, 80.1397),500)

# %% [markdown]
# ### TrueWay Places API

# %%
import requests
import json

def get_hospital_other_info(hospital,source_lat_lng,result_dictionary):
    print(source_lat_lng)
    url = "https://trueway-places.p.rapidapi.com/FindPlacesNearby"

    querystring = {
        "location":  ", ".join(str(coord) for coord in source_lat_lng),
        "type": "hospital",
        "radius": "50000",
        "language": "en"
    }

    headers = {
        "X-RapidAPI-Key": "45ecf3fe21msh9b99573d6cc5214p16214ajsn3275712f1ba3",
        "X-RapidAPI-Host": "trueway-places.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    data = response.json()

    results = data.get('results', [])
    


    for result in results:
        hospital_name = result.get('name', 'N/A')
        if hospital_name == hospital:
            result_dictionary[hospital_name]["Phone Number"] = result.get('phone_number', 'N/A')
      
    return result_dictionary

# %% [markdown]
# ### Iniatialisation Code

# %%
def intialise_lat_lon():
    latitude,longitude = float(input("Enter the accident Latitude: ")), float(input("Enter the accident Longitude: "))

    info_lat_lng = (latitude, longitude)
    result_dictionary = get_hospital_details(info_lat_lng,500)
    print("\nIniatilsed Dictionary :", result_dictionary)
    return result_dictionary

# %% [markdown]
# ### Displaying Latitude Longitude of each Hospital

# %%
def display_lat_lon(result_dictionary):
    for hospital_name, hospital_info in result_dictionary.items():
        print(f"Hospital: {hospital_name}")
        print(f"Latitude: {hospital_info['Latitude']}")
        print(f"Longitude: {hospital_info['Longitude']}")
        print()

# %% [markdown]
# ### Run the TrueWay API

# %%
def run_get_hospital_other_info(result_dictionary):
    for hospital_name, hospital_info in result_dictionary.items():
        result_dictionary = get_hospital_other_info(hospital_name,(hospital_info['Latitude'],hospital_info['Longitude']),result_dictionary)
    return result_dictionary

# %% [markdown]
# ### Final Printing of Emergency Information

# %%
def print_final(result_dictionary):
    for hospital_name, hospital_info in result_dictionary.items():
        if hospital_info['Phone Number'] != 'N/A':
            print(f"Hospital: {hospital_name}")
            print(f"Hospital Emergency Contact Number: {hospital_info['Phone Number']}")
            print(f"Approximate Distance from Accident Spot: {hospital_info['Distance from Source Latitude']}")
            print(f"Latitude: {hospital_info['Latitude']}")
            print(f"Longitude: {hospital_info['Longitude']}")
            print(f"Hospital Address: {hospital_info['Address']}")
            print('\n')

# %% [markdown]
# ### Final Function Calls

# %%
MIT_lat_lng = (12.9480, 80.1397)

# %%
result_dictionary = intialise_lat_lon()
# Out:
# Enter the accident Latitude:  12.9480
# Enter the accident Longitude:  80.1397
# ...

# %%
display_lat_lon(result_dictionary)
# Out:
# Hospital: PARVATHY HOSPITAL
# Latitude: 12.9459046
# Longitude: 80.1365663
#
# Hospital: Sayee Hospitals
# Latitude: 12.9522647
# Longitude: 80.1432823
#
# Hospital: Chennai Krishna Hospital
# Latitude: 12.9464318
# Longitude: 80.13677059999999
#
# Hospital: RK Speciality Hospital
# Latitude: 12.9456956
# Longitude: 80.1415726
#
# Hospital: Gajanan Hospital Pvt Ltd AG Hospital
# Latitude: 12.9504649
# Longitude: 80.1437043
#
# Hospital: Government Hospital, Chrompet
# Latitude: 12.9455076
# Longitude: 80.1356016
#
# Hospital: Dr Kumar's Healthcare
# Latitude: 12.9516226
# Longitude: 80.13918240000001
#
# Hospital: Sudar Hospital
# Latitude: 12.9422327
# Longitude: 80.1408142
#
# Hospital: Sriram hospital
# Latitude: 12.9498088
# Longitude: 80.1350827
#
# Hospital: Balaji Hospital
# Latitude: 12.9534793
# Longitude: 80.1387487
#
# Hospital: BN Sankara Hospital
# Latitude: 12.952298
# Longitude: 80.1436976
#
# Hospital: Hospital
# Latitude: 12.9479602
# Longitude: 80.13758159999999
#
# ...

# %%
result_dictionary = run_get_hospital_other_info(result_dictionary)
# Out:
# (12.9459046, 80.1365663)
# (12.9522647, 80.1432823)
# (12.9464318, 80.13677059999999)
# (12.9456956, 80.1415726)
# (12.9504649, 80.1437043)
# (12.9455076, 80.1356016)
# (12.9516226, 80.13918240000001)
# (12.9422327, 80.1408142)
# (12.9498088, 80.1350827)
# (12.9534793, 80.1387487)
# (12.952298, 80.1436976)
# (12.9479602, 80.13758159999999)
# (12.9425556, 80.1405117)
# (12.9491132, 80.137946)
# (12.9537918, 80.1432586)
# (12.9455587, 80.13434989999999)
# (12.9545325, 80.1377868)
# (12.9530338, 80.1397073)
# (12.9538969, 80.1416902)
# (12.9454026, 80.13983139999999)

# %%
print_final(result_dictionary)
# Out:
# Hospital: PARVATHY HOSPITAL
# Hospital Emergency Contact Number: +914422382248
# Approximate Distance from Accident Spot: 0.41 km
# Latitude: 12.9459046
# Longitude: 80.1365663
# Hospital Address: 241, Grand Southern Trunk Rd, near MIT Bridge, Kamakshi Colony, Chromepet, Chennai
#
#
# Hospital: Sayee Hospitals
# Hospital Emergency Contact Number: +914443575770
# Approximate Distance from Accident Spot: 0.61 km
# Latitude: 12.9522647
# Longitude: 80.1432823
# Hospital Address: No.14, Bashyam Street, Radha Nagar Main Rd, T.Nagar, Radha Nagar, Chromepet, Chennai
#
#
# Hospital: Chennai Krishna Hospital
# Hospital Emergency Contact Number: +919444786535
# Approximate Distance from Accident Spot: 0.36 km
# Latitude: 12.9464318
# Longitude: 80.13677059999999
# Hospital Address: 297, Grand Southern Trunk Rd, near MIT Bridge, Kamakshi Colony, Chromepet, Chennai
#
#
# Hospital: RK Speciality Hospital
# Hospital Emergency Contact Number: +919840670170
# ...

# %%
imp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 imp
#
# NameError: name 'imp' is not defined
